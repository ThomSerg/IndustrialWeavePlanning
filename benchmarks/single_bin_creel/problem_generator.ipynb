# %%
import sys, os, json

# %%
nr_colorss = [1, 2, 3, 4, 5]
nr_item_types = [4]#,7,10]
nr_instances_per_problem = 10
max_nr_colors = 5

# %%
path_in = os.path.join(os.getcwd(), "..", "single_bin", "problems")
path_out = os.path.join(os.getcwd(), "problems")

for nr_colors in nr_colorss:

    for nr_item_type in nr_item_types:
        for y in range(100,900+1,50):
            for x in range(100,y+1,50):
                file_name = str(nr_item_type) + "_" + str(x) + "_" + str(y) 

                file = open(os.path.join(path_in, file_name + ".json"), "r")

                data = json.load(file)

                for data_instance_key, problem_instance in zip(data, range(nr_instances_per_problem)):

                    data_instance = data[data_instance_key]

                    machine_config = data_instance["machine_config"]
                    machine_config["max_creel_colors"] = nr_colors
                    data_instance["machine_config"] = machine_config

                    data_instance["colors"] = [i%max_nr_colors for i in range(nr_item_type)]

                    data[data_instance_key] = data_instance

                    print(problem_instance, data_instance)


                json_object = json.dumps(data, indent=4)

                with open(os.path.join(path_out, file_name + "_" + str(nr_colors) + ".json"), "w") as outfile:
                    outfile.write(json_object)
# Out:
# 0 {'widths': [44, 49, 37, 43], 'heights': [43, 95, 72, 54], 'machine_config': {'width': 100, 'min_length': 100, 'max_length': 100, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 1 {'widths': [82, 35, 24, 29], 'heights': [54, 27, 46, 37], 'machine_config': {'width': 100, 'min_length': 100, 'max_length': 100, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 2 {'widths': [37, 49, 37, 77], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 100, 'min_length': 100, 'max_length': 100, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [41, 35, 38, 54], 'machine_config': {'width': 100, 'min_length': 100, 'max_length': 100, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 100, 'min_length': 100, 'max_length': 100, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 5 {'widths': [67, 46, 31, 66], 'heights': [72, 63, 45, 61], 'machine_config': {'width': 100, 'min_length': 100, 'max_length': 100, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 6 {'widths': [69, 68, 67, 70], 'heights': [65, 71, 47, 31], 'machine_config': {'width': 100, 'min_length': 100, 'max_length': 100, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 100, 'min_length': 100, 'max_length': 100, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 8 {'widths': [72, 55, 25, 66], 'heights': [69, 28, 57, 61], 'machine_config': {'width': 100, 'min_length': 100, 'max_length': 100, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 9 {'widths': [45, 91, 36, 63], 'heights': [94, 52, 34, 49], 'machine_config': {'width': 100, 'min_length': 100, 'max_length': 100, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 0 {'widths': [44, 49, 37, 43], 'heights': [43, 94, 72, 54], 'machine_config': {'width': 100, 'min_length': 150, 'max_length': 150, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [53, 27, 46, 37], 'machine_config': {'width': 100, 'min_length': 150, 'max_length': 150, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 100, 'min_length': 150, 'max_length': 150, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [41, 35, 38, 54], 'machine_config': {'width': 100, 'min_length': 150, 'max_length': 150, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 100, 'min_length': 150, 'max_length': 150, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 5 {'widths': [69, 46, 31, 66], 'heights': [71, 63, 45, 61], 'machine_config': {'width': 100, 'min_length': 150, 'max_length': 150, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 6 {'widths': [69, 70, 67, 70], 'heights': [65, 69, 47, 31], 'machine_config': {'width': 100, 'min_length': 150, 'max_length': 150, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 100, 'min_length': 150, 'max_length': 150, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 8 {'widths': [74, 55, 25, 66], 'heights': [67, 28, 57, 61], 'machine_config': {'width': 100, 'min_length': 150, 'max_length': 150, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 9 {'widths': [45, 95, 36, 63], 'heights': [94, 50, 34, 49], 'machine_config': {'width': 100, 'min_length': 150, 'max_length': 150, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 0 {'widths': [44, 47, 37, 43], 'heights': [43, 98, 72, 54], 'machine_config': {'width': 150, 'min_length': 150, 'max_length': 150, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [54, 27, 46, 37], 'machine_config': {'width': 150, 'min_length': 150, 'max_length': 150, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 150, 'min_length': 150, 'max_length': 150, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [41, 35, 38, 54], 'machine_config': {'width': 150, 'min_length': 150, 'max_length': 150, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 150, 'min_length': 150, 'max_length': 150, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 5 {'widths': [67, 46, 31, 66], 'heights': [73, 63, 45, 61], 'machine_config': {'width': 150, 'min_length': 150, 'max_length': 150, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 6 {'widths': [69, 68, 67, 70], 'heights': [65, 71, 47, 31], 'machine_config': {'width': 150, 'min_length': 150, 'max_length': 150, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 150, 'min_length': 150, 'max_length': 150, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 8 {'widths': [72, 55, 25, 66], 'heights': [69, 28, 57, 61], 'machine_config': {'width': 150, 'min_length': 150, 'max_length': 150, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 9 {'widths': [45, 94, 36, 63], 'heights': [94, 50, 34, 49], 'machine_config': {'width': 150, 'min_length': 150, 'max_length': 150, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 0 {'widths': [44, 49, 37, 43], 'heights': [43, 94, 72, 54], 'machine_config': {'width': 100, 'min_length': 200, 'max_length': 200, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [53, 27, 46, 37], 'machine_config': {'width': 100, 'min_length': 200, 'max_length': 200, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 100, 'min_length': 200, 'max_length': 200, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [41, 35, 38, 54], 'machine_config': {'width': 100, 'min_length': 200, 'max_length': 200, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 100, 'min_length': 200, 'max_length': 200, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 5 {'widths': [69, 46, 31, 66], 'heights': [71, 63, 45, 61], 'machine_config': {'width': 100, 'min_length': 200, 'max_length': 200, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 6 {'widths': [69, 70, 67, 70], 'heights': [65, 69, 47, 31], 'machine_config': {'width': 100, 'min_length': 200, 'max_length': 200, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 100, 'min_length': 200, 'max_length': 200, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 8 {'widths': [74, 55, 25, 66], 'heights': [67, 28, 57, 61], 'machine_config': {'width': 100, 'min_length': 200, 'max_length': 200, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 9 {'widths': [45, 95, 36, 63], 'heights': [94, 50, 34, 49], 'machine_config': {'width': 100, 'min_length': 200, 'max_length': 200, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 0 {'widths': [44, 47, 37, 43], 'heights': [43, 98, 72, 54], 'machine_config': {'width': 150, 'min_length': 200, 'max_length': 200, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [54, 27, 46, 37], 'machine_config': {'width': 150, 'min_length': 200, 'max_length': 200, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 150, 'min_length': 200, 'max_length': 200, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [41, 35, 38, 54], 'machine_config': {'width': 150, 'min_length': 200, 'max_length': 200, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 150, 'min_length': 200, 'max_length': 200, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 5 {'widths': [67, 46, 31, 66], 'heights': [73, 63, 45, 61], 'machine_config': {'width': 150, 'min_length': 200, 'max_length': 200, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 6 {'widths': [69, 68, 67, 70], 'heights': [65, 71, 47, 31], 'machine_config': {'width': 150, 'min_length': 200, 'max_length': 200, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 150, 'min_length': 200, 'max_length': 200, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 8 {'widths': [72, 55, 25, 66], 'heights': [69, 28, 57, 61], 'machine_config': {'width': 150, 'min_length': 200, 'max_length': 200, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 9 {'widths': [45, 94, 36, 63], 'heights': [94, 50, 34, 49], 'machine_config': {'width': 150, 'min_length': 200, 'max_length': 200, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 0 {'widths': [44, 47, 37, 43], 'heights': [43, 98, 72, 54], 'machine_config': {'width': 200, 'min_length': 200, 'max_length': 200, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [54, 27, 46, 37], 'machine_config': {'width': 200, 'min_length': 200, 'max_length': 200, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 200, 'min_length': 200, 'max_length': 200, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [41, 35, 38, 54], 'machine_config': {'width': 200, 'min_length': 200, 'max_length': 200, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 200, 'min_length': 200, 'max_length': 200, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 5 {'widths': [67, 46, 31, 66], 'heights': [73, 63, 45, 61], 'machine_config': {'width': 200, 'min_length': 200, 'max_length': 200, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 6 {'widths': [69, 68, 67, 70], 'heights': [65, 71, 47, 31], 'machine_config': {'width': 200, 'min_length': 200, 'max_length': 200, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 200, 'min_length': 200, 'max_length': 200, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 8 {'widths': [72, 55, 25, 66], 'heights': [69, 28, 57, 61], 'machine_config': {'width': 200, 'min_length': 200, 'max_length': 200, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 9 {'widths': [45, 94, 36, 63], 'heights': [94, 50, 34, 49], 'machine_config': {'width': 200, 'min_length': 200, 'max_length': 200, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 0 {'widths': [44, 49, 37, 43], 'heights': [43, 94, 72, 54], 'machine_config': {'width': 100, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [53, 27, 46, 37], 'machine_config': {'width': 100, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 100, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [42, 35, 38, 54], 'machine_config': {'width': 100, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 100, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 5 {'widths': [69, 46, 31, 66], 'heights': [71, 63, 46, 61], 'machine_config': {'width': 100, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 6 {'widths': [69, 70, 67, 70], 'heights': [65, 69, 47, 31], 'machine_config': {'width': 100, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 100, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 8 {'widths': [74, 55, 25, 66], 'heights': [67, 28, 57, 61], 'machine_config': {'width': 100, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 9 {'widths': [45, 95, 36, 63], 'heights': [95, 50, 34, 49], 'machine_config': {'width': 100, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 0 {'widths': [44, 47, 37, 43], 'heights': [43, 98, 72, 54], 'machine_config': {'width': 150, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [54, 27, 46, 37], 'machine_config': {'width': 150, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 150, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [41, 35, 38, 54], 'machine_config': {'width': 150, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 150, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 5 {'widths': [67, 46, 31, 66], 'heights': [73, 63, 45, 61], 'machine_config': {'width': 150, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 6 {'widths': [69, 68, 67, 70], 'heights': [65, 71, 47, 31], 'machine_config': {'width': 150, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 150, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 8 {'widths': [72, 55, 25, 66], 'heights': [69, 28, 57, 61], 'machine_config': {'width': 150, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 9 {'widths': [45, 94, 36, 63], 'heights': [94, 50, 34, 49], 'machine_config': {'width': 150, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 0 {'widths': [44, 47, 37, 43], 'heights': [43, 98, 72, 54], 'machine_config': {'width': 200, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [54, 27, 46, 37], 'machine_config': {'width': 200, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 200, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [42, 35, 38, 54], 'machine_config': {'width': 200, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 200, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 5 {'widths': [67, 46, 31, 66], 'heights': [73, 63, 46, 61], 'machine_config': {'width': 200, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 6 {'widths': [69, 68, 67, 70], 'heights': [65, 71, 47, 31], 'machine_config': {'width': 200, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 200, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 8 {'widths': [72, 55, 25, 66], 'heights': [69, 28, 57, 61], 'machine_config': {'width': 200, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 9 {'widths': [45, 94, 36, 63], 'heights': [95, 50, 34, 49], 'machine_config': {'width': 200, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 0 {'widths': [44, 47, 37, 43], 'heights': [43, 98, 72, 54], 'machine_config': {'width': 250, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [54, 27, 46, 37], 'machine_config': {'width': 250, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 250, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [41, 35, 38, 54], 'machine_config': {'width': 250, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 250, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 5 {'widths': [67, 46, 31, 66], 'heights': [73, 63, 45, 61], 'machine_config': {'width': 250, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 6 {'widths': [69, 68, 67, 70], 'heights': [65, 71, 47, 31], 'machine_config': {'width': 250, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 250, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 8 {'widths': [72, 55, 25, 66], 'heights': [69, 28, 57, 61], 'machine_config': {'width': 250, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 9 {'widths': [45, 94, 36, 63], 'heights': [94, 50, 34, 49], 'machine_config': {'width': 250, 'min_length': 250, 'max_length': 250, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 0 {'widths': [44, 49, 37, 43], 'heights': [43, 94, 72, 54], 'machine_config': {'width': 100, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [53, 27, 46, 37], 'machine_config': {'width': 100, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 100, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [41, 35, 38, 54], 'machine_config': {'width': 100, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 100, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 5 {'widths': [69, 46, 31, 66], 'heights': [71, 63, 45, 61], 'machine_config': {'width': 100, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 6 {'widths': [69, 70, 67, 70], 'heights': [65, 69, 47, 31], 'machine_config': {'width': 100, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 100, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 8 {'widths': [74, 55, 25, 66], 'heights': [67, 28, 57, 61], 'machine_config': {'width': 100, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 9 {'widths': [45, 95, 36, 63], 'heights': [94, 50, 34, 49], 'machine_config': {'width': 100, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 0 {'widths': [44, 47, 37, 43], 'heights': [43, 98, 72, 54], 'machine_config': {'width': 150, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [54, 27, 46, 37], 'machine_config': {'width': 150, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 150, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [41, 35, 38, 54], 'machine_config': {'width': 150, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 150, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 5 {'widths': [67, 46, 31, 66], 'heights': [73, 63, 45, 61], 'machine_config': {'width': 150, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 6 {'widths': [69, 68, 67, 70], 'heights': [65, 71, 47, 31], 'machine_config': {'width': 150, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 150, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 8 {'widths': [72, 55, 25, 66], 'heights': [69, 28, 57, 61], 'machine_config': {'width': 150, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 9 {'widths': [45, 94, 36, 63], 'heights': [94, 50, 34, 49], 'machine_config': {'width': 150, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 0 {'widths': [44, 47, 37, 43], 'heights': [43, 98, 72, 54], 'machine_config': {'width': 200, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [54, 27, 46, 37], 'machine_config': {'width': 200, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 200, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [41, 35, 38, 54], 'machine_config': {'width': 200, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 200, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 5 {'widths': [67, 46, 31, 66], 'heights': [73, 63, 45, 61], 'machine_config': {'width': 200, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 6 {'widths': [69, 68, 67, 70], 'heights': [65, 71, 47, 31], 'machine_config': {'width': 200, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 200, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 8 {'widths': [72, 55, 25, 66], 'heights': [69, 28, 57, 61], 'machine_config': {'width': 200, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 9 {'widths': [45, 94, 36, 63], 'heights': [94, 50, 34, 49], 'machine_config': {'width': 200, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 0 {'widths': [44, 47, 37, 43], 'heights': [43, 98, 72, 54], 'machine_config': {'width': 250, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [54, 27, 46, 37], 'machine_config': {'width': 250, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 250, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [41, 35, 38, 54], 'machine_config': {'width': 250, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 250, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 5 {'widths': [67, 46, 31, 66], 'heights': [73, 63, 45, 61], 'machine_config': {'width': 250, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 6 {'widths': [69, 68, 67, 70], 'heights': [65, 71, 47, 31], 'machine_config': {'width': 250, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 250, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 8 {'widths': [72, 55, 25, 66], 'heights': [69, 28, 57, 61], 'machine_config': {'width': 250, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 9 {'widths': [45, 94, 36, 63], 'heights': [94, 50, 34, 49], 'machine_config': {'width': 250, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 0 {'widths': [44, 47, 37, 43], 'heights': [43, 98, 72, 54], 'machine_config': {'width': 300, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [54, 27, 46, 37], 'machine_config': {'width': 300, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 300, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [41, 35, 38, 54], 'machine_config': {'width': 300, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 300, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 5 {'widths': [67, 46, 31, 66], 'heights': [73, 63, 45, 61], 'machine_config': {'width': 300, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 6 {'widths': [69, 68, 67, 70], 'heights': [65, 71, 47, 31], 'machine_config': {'width': 300, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 300, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 8 {'widths': [72, 55, 25, 66], 'heights': [69, 28, 57, 61], 'machine_config': {'width': 300, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 9 {'widths': [45, 94, 36, 63], 'heights': [94, 50, 34, 49], 'machine_config': {'width': 300, 'min_length': 300, 'max_length': 300, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 0 {'widths': [44, 49, 37, 43], 'heights': [43, 94, 72, 54], 'machine_config': {'width': 100, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [53, 27, 46, 37], 'machine_config': {'width': 100, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 100, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [41, 35, 38, 54], 'machine_config': {'width': 100, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 100, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 5 {'widths': [69, 46, 31, 66], 'heights': [71, 63, 45, 61], 'machine_config': {'width': 100, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 6 {'widths': [69, 70, 67, 70], 'heights': [65, 69, 47, 31], 'machine_config': {'width': 100, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 100, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 8 {'widths': [74, 55, 25, 66], 'heights': [67, 28, 57, 61], 'machine_config': {'width': 100, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 9 {'widths': [45, 95, 36, 63], 'heights': [94, 50, 34, 49], 'machine_config': {'width': 100, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 0 {'widths': [44, 47, 37, 43], 'heights': [43, 98, 72, 54], 'machine_config': {'width': 150, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [54, 27, 46, 37], 'machine_config': {'width': 150, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 150, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [41, 35, 38, 54], 'machine_config': {'width': 150, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 150, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 5 {'widths': [67, 46, 31, 66], 'heights': [73, 63, 45, 61], 'machine_config': {'width': 150, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 6 {'widths': [69, 68, 67, 70], 'heights': [65, 71, 47, 31], 'machine_config': {'width': 150, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 150, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 8 {'widths': [72, 55, 25, 66], 'heights': [69, 28, 57, 61], 'machine_config': {'width': 150, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 9 {'widths': [45, 94, 36, 63], 'heights': [94, 50, 34, 49], 'machine_config': {'width': 150, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 0 {'widths': [44, 47, 37, 43], 'heights': [43, 98, 72, 54], 'machine_config': {'width': 200, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [54, 27, 46, 37], 'machine_config': {'width': 200, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 200, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [41, 35, 38, 54], 'machine_config': {'width': 200, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 200, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 5 {'widths': [67, 46, 31, 66], 'heights': [73, 63, 45, 61], 'machine_config': {'width': 200, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 6 {'widths': [69, 68, 67, 70], 'heights': [65, 71, 47, 31], 'machine_config': {'width': 200, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 200, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 8 {'widths': [72, 55, 25, 66], 'heights': [69, 28, 57, 61], 'machine_config': {'width': 200, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 9 {'widths': [45, 94, 36, 63], 'heights': [94, 50, 34, 49], 'machine_config': {'width': 200, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 0 {'widths': [44, 47, 37, 43], 'heights': [43, 98, 72, 54], 'machine_config': {'width': 250, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [54, 27, 46, 37], 'machine_config': {'width': 250, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 250, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [41, 35, 38, 54], 'machine_config': {'width': 250, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 250, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 5 {'widths': [67, 46, 31, 66], 'heights': [73, 63, 45, 61], 'machine_config': {'width': 250, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 6 {'widths': [69, 68, 67, 70], 'heights': [65, 71, 47, 31], 'machine_config': {'width': 250, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 250, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 8 {'widths': [72, 55, 25, 66], 'heights': [69, 28, 57, 61], 'machine_config': {'width': 250, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 9 {'widths': [45, 94, 36, 63], 'heights': [94, 50, 34, 49], 'machine_config': {'width': 250, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 0 {'widths': [44, 47, 37, 43], 'heights': [43, 98, 72, 54], 'machine_config': {'width': 300, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [54, 27, 46, 37], 'machine_config': {'width': 300, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 300, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [41, 35, 38, 54], 'machine_config': {'width': 300, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 300, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 5 {'widths': [67, 46, 31, 66], 'heights': [73, 63, 45, 61], 'machine_config': {'width': 300, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 6 {'widths': [69, 68, 67, 70], 'heights': [65, 71, 47, 31], 'machine_config': {'width': 300, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 300, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 8 {'widths': [72, 55, 25, 66], 'heights': [69, 28, 57, 61], 'machine_config': {'width': 300, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 9 {'widths': [45, 94, 36, 63], 'heights': [94, 50, 34, 49], 'machine_config': {'width': 300, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 0 {'widths': [44, 47, 37, 43], 'heights': [43, 98, 72, 54], 'machine_config': {'width': 350, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [54, 27, 46, 37], 'machine_config': {'width': 350, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 350, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [41, 35, 38, 54], 'machine_config': {'width': 350, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 350, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 5 {'widths': [67, 46, 31, 66], 'heights': [73, 63, 45, 61], 'machine_config': {'width': 350, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 6 {'widths': [69, 68, 67, 70], 'heights': [65, 71, 47, 31], 'machine_config': {'width': 350, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 350, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 8 {'widths': [72, 55, 25, 66], 'heights': [69, 28, 57, 61], 'machine_config': {'width': 350, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 9 {'widths': [45, 94, 36, 63], 'heights': [94, 50, 34, 49], 'machine_config': {'width': 350, 'min_length': 350, 'max_length': 350, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 0 {'widths': [44, 49, 37, 43], 'heights': [43, 94, 72, 54], 'machine_config': {'width': 100, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [53, 27, 46, 37], 'machine_config': {'width': 100, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 100, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [41, 35, 38, 54], 'machine_config': {'width': 100, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 100, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 5 {'widths': [69, 46, 31, 66], 'heights': [71, 63, 45, 61], 'machine_config': {'width': 100, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 6 {'widths': [69, 70, 67, 70], 'heights': [65, 69, 47, 31], 'machine_config': {'width': 100, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 100, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 8 {'widths': [74, 55, 25, 66], 'heights': [67, 28, 57, 61], 'machine_config': {'width': 100, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 9 {'widths': [45, 95, 36, 63], 'heights': [94, 50, 34, 49], 'machine_config': {'width': 100, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 0 {'widths': [44, 47, 37, 43], 'heights': [43, 98, 72, 54], 'machine_config': {'width': 150, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [54, 27, 46, 37], 'machine_config': {'width': 150, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 150, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [41, 35, 38, 54], 'machine_config': {'width': 150, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 150, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 5 {'widths': [67, 46, 31, 66], 'heights': [73, 63, 45, 61], 'machine_config': {'width': 150, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 6 {'widths': [69, 68, 67, 70], 'heights': [65, 71, 47, 31], 'machine_config': {'width': 150, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 150, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 8 {'widths': [72, 55, 25, 66], 'heights': [69, 28, 57, 61], 'machine_config': {'width': 150, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 9 {'widths': [45, 94, 36, 63], 'heights': [94, 50, 34, 49], 'machine_config': {'width': 150, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 0 {'widths': [44, 47, 37, 43], 'heights': [43, 98, 72, 54], 'machine_config': {'width': 200, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [54, 27, 46, 37], 'machine_config': {'width': 200, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 200, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [41, 35, 38, 54], 'machine_config': {'width': 200, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 200, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 5 {'widths': [67, 46, 31, 66], 'heights': [73, 63, 45, 61], 'machine_config': {'width': 200, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 6 {'widths': [69, 68, 67, 70], 'heights': [65, 71, 47, 31], 'machine_config': {'width': 200, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 200, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 8 {'widths': [72, 55, 25, 66], 'heights': [69, 28, 57, 61], 'machine_config': {'width': 200, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 9 {'widths': [45, 94, 36, 63], 'heights': [94, 50, 34, 49], 'machine_config': {'width': 200, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 0 {'widths': [44, 47, 37, 43], 'heights': [43, 98, 72, 54], 'machine_config': {'width': 250, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [54, 27, 46, 37], 'machine_config': {'width': 250, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 250, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [42, 35, 38, 54], 'machine_config': {'width': 250, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 250, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 5 {'widths': [67, 46, 31, 66], 'heights': [73, 63, 46, 61], 'machine_config': {'width': 250, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 6 {'widths': [69, 68, 67, 70], 'heights': [65, 71, 47, 31], 'machine_config': {'width': 250, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 250, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 8 {'widths': [72, 55, 25, 66], 'heights': [69, 28, 57, 61], 'machine_config': {'width': 250, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 9 {'widths': [45, 94, 36, 63], 'heights': [95, 50, 34, 49], 'machine_config': {'width': 250, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 0 {'widths': [44, 47, 37, 43], 'heights': [43, 98, 72, 54], 'machine_config': {'width': 300, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [54, 27, 46, 37], 'machine_config': {'width': 300, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 300, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [41, 35, 38, 54], 'machine_config': {'width': 300, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 300, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 5 {'widths': [67, 46, 31, 66], 'heights': [73, 63, 45, 61], 'machine_config': {'width': 300, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 6 {'widths': [69, 68, 67, 70], 'heights': [65, 71, 47, 31], 'machine_config': {'width': 300, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 300, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 8 {'widths': [72, 55, 25, 66], 'heights': [69, 28, 57, 61], 'machine_config': {'width': 300, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 9 {'widths': [45, 94, 36, 63], 'heights': [94, 50, 34, 49], 'machine_config': {'width': 300, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 0 {'widths': [44, 47, 37, 43], 'heights': [43, 98, 72, 54], 'machine_config': {'width': 350, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [54, 27, 46, 37], 'machine_config': {'width': 350, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 350, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [41, 35, 38, 54], 'machine_config': {'width': 350, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 350, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 5 {'widths': [67, 46, 31, 66], 'heights': [73, 63, 45, 61], 'machine_config': {'width': 350, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 6 {'widths': [69, 68, 67, 70], 'heights': [65, 71, 47, 31], 'machine_config': {'width': 350, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 350, 'min_length': 400, 'max_length': 400, 'max_creel_colors': 1}, 'colors': [0, 0, 0, 0]}
# ...
# 1 {'widths': [83, 35, 24, 29], 'heights': [54, 27, 46, 37], 'machine_config': {'width': 500, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 500, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [41, 35, 38, 54], 'machine_config': {'width': 500, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 500, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 5 {'widths': [67, 46, 31, 66], 'heights': [73, 63, 45, 61], 'machine_config': {'width': 500, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 6 {'widths': [69, 68, 67, 70], 'heights': [65, 71, 47, 31], 'machine_config': {'width': 500, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 500, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 8 {'widths': [72, 55, 25, 66], 'heights': [69, 28, 57, 61], 'machine_config': {'width': 500, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 9 {'widths': [45, 94, 36, 63], 'heights': [94, 50, 34, 49], 'machine_config': {'width': 500, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 0 {'widths': [44, 47, 37, 43], 'heights': [43, 98, 72, 54], 'machine_config': {'width': 550, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [54, 27, 46, 37], 'machine_config': {'width': 550, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 550, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [41, 35, 38, 54], 'machine_config': {'width': 550, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 550, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 5 {'widths': [67, 46, 31, 66], 'heights': [73, 63, 45, 61], 'machine_config': {'width': 550, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 6 {'widths': [69, 68, 67, 70], 'heights': [65, 71, 47, 31], 'machine_config': {'width': 550, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 550, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 8 {'widths': [72, 55, 25, 66], 'heights': [69, 28, 57, 61], 'machine_config': {'width': 550, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 9 {'widths': [45, 94, 36, 63], 'heights': [94, 50, 34, 49], 'machine_config': {'width': 550, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 0 {'widths': [44, 47, 37, 43], 'heights': [43, 98, 72, 54], 'machine_config': {'width': 600, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [54, 27, 46, 37], 'machine_config': {'width': 600, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 600, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [41, 35, 38, 54], 'machine_config': {'width': 600, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 600, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 5 {'widths': [67, 46, 31, 66], 'heights': [73, 63, 45, 61], 'machine_config': {'width': 600, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 6 {'widths': [69, 68, 67, 70], 'heights': [65, 71, 47, 31], 'machine_config': {'width': 600, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 600, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 8 {'widths': [72, 55, 25, 66], 'heights': [69, 28, 57, 61], 'machine_config': {'width': 600, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 9 {'widths': [45, 94, 36, 63], 'heights': [94, 50, 34, 49], 'machine_config': {'width': 600, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 0 {'widths': [44, 47, 37, 43], 'heights': [43, 98, 72, 54], 'machine_config': {'width': 650, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [54, 27, 46, 37], 'machine_config': {'width': 650, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 650, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [41, 35, 38, 54], 'machine_config': {'width': 650, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 650, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 5 {'widths': [67, 46, 31, 66], 'heights': [73, 63, 45, 61], 'machine_config': {'width': 650, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 6 {'widths': [69, 68, 67, 70], 'heights': [65, 71, 47, 31], 'machine_config': {'width': 650, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 650, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 8 {'widths': [72, 55, 25, 66], 'heights': [69, 28, 57, 61], 'machine_config': {'width': 650, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 9 {'widths': [45, 94, 36, 63], 'heights': [94, 50, 34, 49], 'machine_config': {'width': 650, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 0 {'widths': [44, 47, 37, 43], 'heights': [43, 98, 72, 54], 'machine_config': {'width': 700, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [54, 27, 46, 37], 'machine_config': {'width': 700, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 700, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [41, 35, 38, 54], 'machine_config': {'width': 700, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 700, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 5 {'widths': [67, 46, 31, 66], 'heights': [73, 63, 45, 61], 'machine_config': {'width': 700, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 6 {'widths': [69, 68, 67, 70], 'heights': [65, 71, 47, 31], 'machine_config': {'width': 700, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 700, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 8 {'widths': [72, 55, 25, 66], 'heights': [69, 28, 57, 61], 'machine_config': {'width': 700, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 9 {'widths': [45, 94, 36, 63], 'heights': [94, 50, 34, 49], 'machine_config': {'width': 700, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 0 {'widths': [44, 47, 37, 43], 'heights': [43, 98, 72, 54], 'machine_config': {'width': 750, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [54, 27, 46, 37], 'machine_config': {'width': 750, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 750, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [41, 35, 38, 54], 'machine_config': {'width': 750, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 750, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 5 {'widths': [67, 46, 31, 66], 'heights': [73, 63, 45, 61], 'machine_config': {'width': 750, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 6 {'widths': [69, 68, 67, 70], 'heights': [65, 71, 47, 31], 'machine_config': {'width': 750, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 750, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 8 {'widths': [72, 55, 25, 66], 'heights': [69, 28, 57, 61], 'machine_config': {'width': 750, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 9 {'widths': [45, 94, 36, 63], 'heights': [94, 50, 34, 49], 'machine_config': {'width': 750, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 0 {'widths': [44, 47, 37, 43], 'heights': [43, 98, 72, 54], 'machine_config': {'width': 800, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [54, 27, 46, 37], 'machine_config': {'width': 800, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 800, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [41, 35, 38, 54], 'machine_config': {'width': 800, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 800, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 5 {'widths': [67, 46, 31, 66], 'heights': [73, 63, 45, 61], 'machine_config': {'width': 800, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 6 {'widths': [69, 68, 67, 70], 'heights': [65, 71, 47, 31], 'machine_config': {'width': 800, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 800, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 8 {'widths': [72, 55, 25, 66], 'heights': [69, 28, 57, 61], 'machine_config': {'width': 800, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 9 {'widths': [45, 94, 36, 63], 'heights': [94, 50, 34, 49], 'machine_config': {'width': 800, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 0 {'widths': [44, 47, 37, 43], 'heights': [43, 98, 72, 54], 'machine_config': {'width': 850, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [54, 27, 46, 37], 'machine_config': {'width': 850, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 850, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [41, 35, 38, 54], 'machine_config': {'width': 850, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 850, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 5 {'widths': [67, 46, 31, 66], 'heights': [73, 63, 45, 61], 'machine_config': {'width': 850, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 6 {'widths': [69, 68, 67, 70], 'heights': [65, 71, 47, 31], 'machine_config': {'width': 850, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 850, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 8 {'widths': [72, 55, 25, 66], 'heights': [69, 28, 57, 61], 'machine_config': {'width': 850, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 9 {'widths': [45, 94, 36, 63], 'heights': [94, 50, 34, 49], 'machine_config': {'width': 850, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 0 {'widths': [44, 47, 37, 43], 'heights': [43, 98, 72, 54], 'machine_config': {'width': 900, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 1 {'widths': [83, 35, 24, 29], 'heights': [54, 27, 46, 37], 'machine_config': {'width': 900, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 2 {'widths': [37, 49, 37, 78], 'heights': [24, 28, 63, 57], 'machine_config': {'width': 900, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 3 {'widths': [25, 60, 65, 56], 'heights': [41, 35, 38, 54], 'machine_config': {'width': 900, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 4 {'widths': [34, 49, 82, 62], 'heights': [35, 72, 36, 62], 'machine_config': {'width': 900, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 5 {'widths': [67, 46, 31, 66], 'heights': [73, 63, 45, 61], 'machine_config': {'width': 900, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 6 {'widths': [69, 68, 67, 70], 'heights': [65, 71, 47, 31], 'machine_config': {'width': 900, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 7 {'widths': [83, 47, 20, 88], 'heights': [50, 28, 43, 40], 'machine_config': {'width': 900, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 8 {'widths': [72, 55, 25, 66], 'heights': [69, 28, 57, 61], 'machine_config': {'width': 900, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}
# 9 {'widths': [45, 94, 36, 63], 'heights': [94, 50, 34, 49], 'machine_config': {'width': 900, 'min_length': 900, 'max_length': 900, 'max_creel_colors': 5}, 'colors': [0, 1, 2, 3]}

# %%
file = os.path.join(os.getcwd(), "main")
